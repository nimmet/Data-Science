# %%
import pandas as pd

# %%
houses = pd.read_csv("C:\Data_Science\Python_Data_Analyse_Visualization/data/kc_house_data.csv")

# %%
houses.min()
# Out:
# id                       1000102
# date             20140502T000000
# price                    75000.0
# bedrooms                       0
# bathrooms                    0.0
# sqft_living                  290
# sqft_lot                     520
# floors                       1.0
# waterfront                     0
# view                           0
# condition                      1
# grade                          1
# sqft_above                   290
# sqft_basement                  0
# yr_built                    1900
# yr_renovated                   0
# zipcode                    98001
# lat                      47.1559
# long                    -122.519
# sqft_living15                399
# sqft_lot15                   651
# dtype: object

# %%
houses.max()
# Out:
# id                    9900000190
# date             20150527T000000
# price                  7700000.0
# bedrooms                      33
# bathrooms                    8.0
# sqft_living                13540
# sqft_lot                 1651359
# floors                       3.5
# waterfront                     1
# view                           4
# condition                      5
# grade                         13
# sqft_above                  9410
# sqft_basement               4820
# yr_built                    2015
# yr_renovated                2015
# zipcode                    98199
# lat                      47.7776
# long                    -121.315
# sqft_living15               6210
# sqft_lot15                871200
# dtype: object

# %%
pwd
# Out:
# 'C:\\Data_Science\\Python_Data_Analyse_Visualization\\05_Basic_DataFrame_methods_computations'

# %%
netflix  = pd.read_csv("C:/Data_Science/Python_Data_Analyse_Visualization\data\netflix_titles.csv")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18244/1461941508.py in <module>
# ----> 1 netflix  = pd.read_csv("C:/Data_Science/Python_Data_Analyse_Visualization\data\netflix_titles.csv")
#
# ~\miniconda3\envs\ML\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
houses.count()
# Out:
# id               21613
# date             21613
# price            21613
# bedrooms         21613
# bathrooms        21613
# sqft_living      21613
# sqft_lot         21613
# floors           21613
# waterfront       21613
# view             21613
# condition        21613
# grade            21613
# sqft_above       21613
# sqft_basement    21613
# yr_built         21613
# yr_renovated     21613
# zipcode          21613
# lat              21613
# long             21613
# sqft_living15    21613
# sqft_lot15       21613
# dtype: int64

# %%
titanic  = pd.read_csv("C:/Data_Science/Python_Data_Analyse_Visualization/data/titanic.csv")

# %%
titanic.mode()
# Out:
#    pclass  survived                  name   sex  age  sibsp  parch    ticket  \
# 0     3.0       0.0  Connolly, Miss. Kate  male    ?    0.0    0.0  CA. 2343
# 1     NaN       NaN      Kelly, Mr. James   NaN  NaN    NaN    NaN       NaN
#
#    fare cabin embarked boat body home.dest
# 0  8.05     ?        S    ?    ?         ?
# 1   NaN   NaN      NaN  NaN  NaN       NaN

# %%
houses.mode()
# Out:
#             id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  795000620.0  20140623T000000  350000.0       3.0        2.5       1300.0
# 1          NaN              NaN  450000.0       NaN        NaN          NaN
# 2          NaN              NaN       NaN       NaN        NaN          NaN
# 3          NaN              NaN       NaN       NaN        NaN          NaN
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0    5000.0     1.0         0.0   0.0  ...    7.0      1300.0            0.0
# 1       NaN     NaN         NaN   NaN  ...    NaN         NaN            NaN
# 2       NaN     NaN         NaN   NaN  ...    NaN         NaN            NaN
# 3       NaN     NaN         NaN   NaN  ...    NaN         NaN            NaN
#
#    yr_built  yr_renovated  zipcode      lat    long  sqft_living15  sqft_lot15
# 0    2014.0           0.0  98103.0  47.5322 -122.29         1540.0      5000.0
# ...

# %%
titanic.describe()
# Out:
#             pclass     survived        sibsp        parch
# count  1309.000000  1309.000000  1309.000000  1309.000000
# mean      2.294882     0.381971     0.498854     0.385027
# std       0.837836     0.486055     1.041658     0.865560
# min       1.000000     0.000000     0.000000     0.000000
# 25%       2.000000     0.000000     0.000000     0.000000
# 50%       3.000000     0.000000     0.000000     0.000000
# 75%       3.000000     1.000000     1.000000     0.000000
# max       3.000000     1.000000     8.000000     9.000000

# %%
titanic.describe(include=["object"])
# Out:
#                         name   sex   age    ticket  fare cabin embarked  boat  \
# count                   1309  1309  1309      1309  1309  1309     1309  1309
# unique                  1307     2    99       929   282   187        4    28
# top     Connolly, Miss. Kate  male     ?  CA. 2343  8.05     ?        S     ?
# freq                       2   843   263        11    60  1014      914   823
#
#         body home.dest
# count   1309      1309
# unique   122       370
# top        ?         ?
# freq    1188       564

# %%
titanic.describe(include=["O"])
# Out:
#                         name   sex   age    ticket  fare cabin embarked  boat  \
# count                   1309  1309  1309      1309  1309  1309     1309  1309
# unique                  1307     2    99       929   282   187        4    28
# top     Connolly, Miss. Kate  male     ?  CA. 2343  8.05     ?        S     ?
# freq                       2   843   263        11    60  1014      914   823
#
#         body home.dest
# count   1309      1309
# unique   122       370
# top        ?         ?
# freq    1188       564

# %%
houses.describe(include=["O"])
# Out:
#                    date
# count             21613
# unique              372
# top     20140623T000000
# freq                142
