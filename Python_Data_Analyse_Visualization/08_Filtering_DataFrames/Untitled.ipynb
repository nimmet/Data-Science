# %%
import pandas as pd

# %%
"C:\Data_Science\Python_Data_Analyse_Visualization\"
# Out:
#   File "C:\Users\namtu\AppData\Local\Temp/ipykernel_5896/599660925.py", line 1
#     "C:\Data_Science\Python_Data_Analyse_Visualization\"
#                                                         ^
# SyntaxError: EOL while scanning string literal

# %%
house = pd.read_csv("C:/Data_Science/Python_Data_Analyse_Visualization/data/kc_house_data.csv")
titanic = pd.read_csv("C:/Data_Science/Python_Data_Analyse_Visualization/data/titanic.csv")
netflix  = pd.read_csv("C:/Data_Science/Python_Data_Analyse_Visualization/data/netflix_titles.csv",sep="|", index_col=0)

# %%
titanic.loc[17:20,["name","sex","age"]]
# Out:
#                                                name     sex age
# 17  Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50
# 18                            Bazzani, Miss. Albina  female  32
# 19                             Beattie, Mr. Thomson    male  36
# 20                    Beckwith, Mr. Richard Leonard    male  37

# %%
titanic.loc[17:200,["name","sex","age","survived"]][titanic.survived == 0]
# Out:
# C:\Users\namtu\AppData\Local\Temp/ipykernel_5896/3449891248.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   titanic.loc[17:200,["name","sex","age","survived"]][titanic.survived == 0]
#                              name   sex age  survived
# 19           Beattie, Mr. Thomson  male  36         0
# 25            Birnbaum, Mr. Jakob  male  25         0
# 30   Blackwell, Mr. Stephen Weart  male  45         0
# 34       Borebank, Mr. John James  male  42         0
# 38        Brady, Mr. John Bertram  male  41         0
# ..                            ...   ...  ..       ...
# 189        Long, Mr. Milton Clyde  male  29         0
# 191    Loring, Mr. Joseph Holland  male  30         0
# 194      Maguire, Mr. John Edward  male  30         0
# 197     Marvin, Mr. Daniel Warner  male  19         0
# 200  McCaffry, Mr. Thomas Francis  male  46         0
#
# [62 rows x 4 columns]

# %%
titanic.loc[17:200,["name","sex","age","survived"]][titanic.sex == "male"]
# Out:
# C:\Users\namtu\AppData\Local\Temp/ipykernel_5896/4043390821.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   titanic.loc[17:200,["name","sex","age","survived"]][titanic.sex == "male"]
#                               name   sex age  survived
# 19            Beattie, Mr. Thomson  male  36         0
# 20   Beckwith, Mr. Richard Leonard  male  37         1
# 22           Behr, Mr. Karl Howell  male  26         1
# 25             Birnbaum, Mr. Jakob  male  25         0
# 26         Bishop, Mr. Dickinson H  male  25         1
# ..                             ...   ...  ..       ...
# 191     Loring, Mr. Joseph Holland  male  30         0
# 194       Maguire, Mr. John Edward  male  30         0
# 196           Marechal, Mr. Pierre  male   ?         1
# 197      Marvin, Mr. Daniel Warner  male  19         0
# 200   McCaffry, Mr. Thomas Francis  male  46         0
#
# [95 rows x 4 columns]

# %%
titanic.loc[10:20][titanic.sex =="female"]
# Out:
# C:\Users\namtu\AppData\Local\Temp/ipykernel_5896/1937401190.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   titanic.loc[10:20][titanic.sex =="female"]
#     pclass  survived                                               name  \
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12       1         1                      Aubart, Mme. Leontine Pauline
# 13       1         1                       Barber, Miss. Ellen 'Nellie'
# 17       1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 18       1         1                              Bazzani, Miss. Albina
#
#        sex age  sibsp  parch    ticket      fare    cabin embarked boat body  \
# 11  female  18      1      0  PC 17757   227.525  C62 C64        C    4    ?
# 12  female  24      0      0  PC 17477      69.3      B35        C    9    ?
# 13  female  26      0      0     19877     78.85        ?        S    6    ?
# ...

# %%
titanic[10:20][titanic.sex=="female"]
# Out:
# C:\Users\namtu\AppData\Local\Temp/ipykernel_5896/2259589239.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   titanic[10:20][titanic.sex=="female"]
#     pclass  survived                                               name  \
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12       1         1                      Aubart, Mme. Leontine Pauline
# 13       1         1                       Barber, Miss. Ellen 'Nellie'
# 17       1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 18       1         1                              Bazzani, Miss. Albina
#
#        sex age  sibsp  parch    ticket      fare    cabin embarked boat body  \
# 11  female  18      1      0  PC 17757   227.525  C62 C64        C    4    ?
# 12  female  24      0      0  PC 17477      69.3      B35        C    9    ?
# 13  female  26      0      0     19877     78.85        ?        S    6    ?
# ...

# %%
titanic[titanic.pclass !=1].pclass.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
house[house["bedrooms"].between(5,7)].bedrooms.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
house[house["grade"].between(11,13)]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 70     1525059190  20140912T000000  1040000.0         5       3.25
# 153    7855801670  20150401T000000  2250000.0         4       3.25
# 269    7960900060  20150504T000000  2900000.0         4       3.25
# 270    4054500390  20141007T000000  1365000.0         4       4.75
# ...           ...              ...        ...       ...        ...
# 21532   324069112  20140617T000000  1325000.0         4       4.00
# 21548  8835770330  20140819T000000  1057000.0         2       1.50
# 21551  1561750040  20141224T000000  1375000.0         5       4.50
# 21590  7430200100  20140514T000000  1222500.0         4       3.50
# 21600   249000205  20141015T000000  1537000.0         5       3.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 5             5420    101930     1.0           0     0  ...     11
# ...

# %%
netflix[netflix.country.isin(["Norway","Turkey","Japan"])].country.value_counts()
# Out:
# Japan     245
# Turkey    105
# Norway     11
# Name: country, dtype: int64

# %%
netflix[netflix.country.isin(["Norway","Turkey"])]
# Out:
#      show_id     type                                         title  \
# 21       s22  TV Show                        Resurrection: Ertugrul
# 703     s704  TV Show                                      The Gift
# 906     s907    Movie  Have You Ever Seen Fireflies? - Theatre Play
# 972     s973  TV Show                                         Fatma
# 976     s977    Movie                                  Among Family
# ...      ...      ...                                           ...
# 8316   s8317  TV Show                           The Future of Water
# 8682   s8683    Movie                               Vizontele Tuuba
# 8720   s8721  TV Show                     What Happens to My Family
# 8749   s8750  TV Show                                    Winter Sun
# 8796   s8797  TV Show                                    Yunus Emre
#
#             director                                               cast  \
# 21               NaN  Engin Altan Düzyatan, Serdar Gökhan, Hülya Dar...
# ...

# %%
titanic[(titanic.survived == 1) & (titanic.sex == "female") & (titanic.age == "25")]
# Out:
#      pclass  survived                                          name     sex  \
# 144       1         1  Harder, Mrs. George Achilles (Dorothy Annan)  female
# 370       2         1                   Christy, Miss. Julie Rachel  female
# 557       2         1  Shelley, Mrs. William (Imanita Parrish Hall)  female
#
#     age  sibsp  parch  ticket     fare cabin embarked boat body  \
# 144  25      1      0   11765  55.4417   E50        C    5    ?
# 370  25      1      1  237789       30     ?        S   12    ?
# 557  25      0      1  230433       26     ?        S   12    ?
#
#           home.dest
# 144    Brooklyn, NY
# 370          London
# 557  Deer Lodge, MT

# %%
df = titanic.head(20)
women = [titanic.sex == "female"]
df[(titanic.sex == "female")]
# Out:
# C:\Users\namtu\AppData\Local\Temp/ipykernel_5896/3360614646.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[(titanic.sex == "female")]
#     pclass  survived                                               name  \
# 0        1         1                      Allen, Miss. Elisabeth Walton
# 2        1         0                       Allison, Miss. Helen Loraine
# 4        1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 6        1         1                  Andrews, Miss. Kornelia Theodosia
# 8        1         1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12       1         1                      Aubart, Mme. Leontine Pauline
# 13       1         1                       Barber, Miss. Ellen 'Nellie'
# 17       1         1    Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 18       1         1                              Bazzani, Miss. Albina
#
# ...

# %%
df[~(titanic.sex == "female")] # we can use ~ to change the  women to men
# Out:
# C:\Users\namtu\AppData\Local\Temp/ipykernel_5896/3885800250.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[~(titanic.sex == "female")] # we can use ~ to change the  women to men
#     pclass  survived                                  name   sex     age  \
# 1        1         1        Allison, Master. Hudson Trevor  male  0.9167
# 3        1         0  Allison, Mr. Hudson Joshua Creighton  male      30
# 5        1         1                   Anderson, Mr. Harry  male      48
# 7        1         0                Andrews, Mr. Thomas Jr  male      39
# 9        1         0               Artagaveytia, Mr. Ramon  male      71
# 10       1         0                Astor, Col. John Jacob  male      47
# 14       1         1  Barkworth, Mr. Algernon Henry Wilson  male      80
# 15       1         0                   Baumann, Mr. John D  male       ?
# 16       1         0              Baxter, Mr. Quigg Edmond  male      24
# ...

# %%
netflix[(netflix.director.isna())]
# Out:
#      show_id     type                                title director  \
# 1         s2  TV Show                        Blood & Water      NaN
# 3         s4  TV Show                Jailbirds New Orleans      NaN
# 4         s5  TV Show                         Kota Factory      NaN
# 10       s11  TV Show  Vendetta: Truth, Lies and The Mafia      NaN
# 14       s15  TV Show      Crime Stories: India Detectives      NaN
# ...      ...      ...                                  ...      ...
# 8795   s8796  TV Show                      Yu-Gi-Oh! Arc-V      NaN
# 8796   s8797  TV Show                           Yunus Emre      NaN
# 8797   s8798  TV Show                            Zak Storm      NaN
# 8800   s8801  TV Show                   Zindagi Gulzar Hai      NaN
# 8803   s8804  TV Show                          Zombie Dumb      NaN
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...

# %%
netflix[(netflix.director.notna())]
# Out:
#      show_id     type                             title  \
# 0         s1    Movie              Dick Johnson Is Dead
# 2         s3  TV Show                         Ganglands
# 5         s6  TV Show                     Midnight Mass
# 6         s7    Movie  My Little Pony: A New Generation
# 7         s8    Movie                           Sankofa
# ...      ...      ...                               ...
# 8801   s8802    Movie                           Zinzana
# 8802   s8803    Movie                            Zodiac
# 8804   s8805    Movie                        Zombieland
# 8805   s8806    Movie                              Zoom
# 8806   s8807    Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 2                   Julien Leclercq
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# ...                             ...
# ...

# %%
netflix[~(netflix.director.isna())]
# Out:
#      show_id     type                             title  \
# 0         s1    Movie              Dick Johnson Is Dead
# 2         s3  TV Show                         Ganglands
# 5         s6  TV Show                     Midnight Mass
# 6         s7    Movie  My Little Pony: A New Generation
# 7         s8    Movie                           Sankofa
# ...      ...      ...                               ...
# 8801   s8802    Movie                           Zinzana
# 8802   s8803    Movie                            Zodiac
# 8804   s8805    Movie                        Zombieland
# 8805   s8806    Movie                              Zoom
# 8806   s8807    Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 2                   Julien Leclercq
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# ...                             ...
# ...

# %%
titanic[titanic.sex =="female"].survived.value_counts()
# Out:
# 1    339
# 0    127
# Name: survived, dtype: int64

# %%
titanic[titanic.sex =="male"].survived.value_counts()
# Out:
# 0    682
# 1    161
# Name: survived, dtype: int64

# %%
titanic[titanic.sex =="male"].survived.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='survived'>

# %%
titanic[~(titanic.sex =="male")].survived.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='survived'>

# %%
house[house.price > 3000000].zipcode.value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>
