# %%
import pandas as pd
import matplotlib.pyplot as plt
house = pd.read_csv("C:/Data_Science/Python_Data_Analyse_Visualization/data/kc_house_data.csv")
titanic = pd.read_csv("C:/Data_Science/Python_Data_Analyse_Visualization/data/titanic.csv")
netflix  = pd.read_csv("C:/Data_Science/Python_Data_Analyse_Visualization/data/netflix_titles.csv",sep="|", index_col=0)
btc = pd.read_csv("C:/Data_Science/Python_Data_Analyse_Visualization/data/coin_Bitcoin.csv")
countries = pd.read_csv("C:/Data_Science/Python_Data_Analyse_Visualization/data/world-happiness-report-2021.csv", index_col=0)
car = pd.read_csv("C:/Data_Science/Python_Data_Analyse_Visualization/data/car_stocks.csv")
pops = pd.read_csv("C:/Data_Science/Python_Data_Analyse_Visualization/data/state_pops.csv")

# %%
titanic.groupby(["pclass","sex"])[["survived","age"]].mean()
# Out:
#                survived
# pclass sex
# 1      female  0.965278
#        male    0.340782
# 2      female  0.886792
#        male    0.146199
# 3      female  0.490741
#        male    0.152130

# %%
titanic.groupby(["pclass","sex"]).mean()
# Out:
#                survived     sibsp     parch
# pclass sex
# 1      female  0.965278  0.555556  0.472222
#        male    0.340782  0.340782  0.279330
# 2      female  0.886792  0.500000  0.650943
#        male    0.146199  0.327485  0.192982
# 3      female  0.490741  0.791667  0.731481
#        male    0.152130  0.470588  0.255578

# %%
pops
# Out:
#      state  year   population
# 0       AL  2012    4817528.0
# 1       AL  2010    4785570.0
# 2       AL  2011    4801627.0
# 3       AL  2009    4757938.0
# 4       AL  2013    4833722.0
# ...    ...   ...          ...
# 1267   USA  2013  316128839.0
# 1268   USA  2009  306771529.0
# 1269   USA  2010  309326295.0
# 1270   USA  2011  311582564.0
# 1271   USA  2012  313873685.0
#
# [1272 rows x 3 columns]

# %%
pops.set_index(["state","year"],inplace=True)

# %%
pops
# Out:
#              population
# state year
# AL    2012    4817528.0
#       2010    4785570.0
#       2011    4801627.0
#       2009    4757938.0
#       2013    4833722.0
# ...                 ...
# USA   2013  316128839.0
#       2009  306771529.0
#       2010  309326295.0
#       2011  311582564.0
#       2012  313873685.0
#
# [1272 rows x 1 columns]

# %%
pops.sort_index(level=1)
# Out:
#             population
# state year
# AK    1990    553290.0
# AL    1990   4050055.0
# AR    1990   2356586.0
# AZ    1990   3684097.0
# CA    1990  29959515.0
# ...                ...
# VT    2013    626630.0
# WA    2013   6971406.0
# WI    2013   5742713.0
# WV    2013   1854304.0
# WY    2013    582658.0
#
# [1272 rows x 1 columns]

# %%
pops.sort_index(level=0)
# Out:
#             population
# state year
# AK    1990    553290.0
#       1991    570193.0
#       1992    588736.0
#       1993    599434.0
#       1994    603308.0
# ...                ...
# WY    2009    559851.0
#       2010    564222.0
#       2011    567329.0
#       2012    576626.0
#       2013    582658.0
#
# [1272 rows x 1 columns]

# %%
pops.sort_index(level=[1,0],ascending=[False,True])
# Out:
#             population
# state year
# AK    2013    735132.0
# AL    2013   4833722.0
# AR    2013   2959373.0
# AZ    2013   6626624.0
# CA    2013  38332521.0
# ...                ...
# VT    1990    564798.0
# WA    1990   4903043.0
# WI    1990   4904562.0
# WV    1990   1792548.0
# WY    1990    453690.0
#
# [1272 rows x 1 columns]

# %%
pops.loc[['CA',"AL","AZ"]].plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='state,year'>

# %%
pops.loc[['CA']].plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='state,year'>

# %%
pops.sort_index(level=[0,1],ascending=[True,True])
# Out:
#             population
# state year
# AK    1990    553290.0
#       1991    570193.0
#       1992    588736.0
#       1993    599434.0
#       1994    603308.0
# ...                ...
# WY    2009    559851.0
#       2010    564222.0
#       2011    567329.0
#       2012    576626.0
#       2013    582658.0
#
# [1272 rows x 1 columns]

# %%
pops
# Out:
#              population
# state year
# AL    2012    4817528.0
#       2010    4785570.0
#       2011    4801627.0
#       2009    4757938.0
#       2013    4833722.0
# ...                 ...
# USA   2013  316128839.0
#       2009  306771529.0
#       2010  309326295.0
#       2011  311582564.0
#       2012  313873685.0
#
# [1272 rows x 1 columns]

# %%
pops.loc[("AK",1990):("AK",2000)]
# Out:
# ---------------------------------------------------------------------------
# UnsortedIndexError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10340/879809692.py in <module>
# ----> 1 pops.loc[("AK",1990):("AK",2000)]
#
# ~\miniconda3\envs\ML\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~\miniconda3\envs\ML\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1140         if isinstance(key, slice):
#    1141             self._validate_key(key, axis)
# -> 1142             return self._get_slice_axis(key, axis=axis)
#    1143         elif com.is_bool_indexer(key):
#    1144             return self._getbool_axis(key, axis=axis)
#
# ...

# %%
pops.loc["CA",1990]
# Out:
# population    29959515.0
# Name: (CA, 1990), dtype: float64

# %%
pops.loc["CA"]
# Out:
#       population
# year
# 2012  37999878.0
# 2011  37668681.0
# 2010  37333601.0
# 2013  38332521.0
# 2009  36961229.0
# 2007  36250311.0
# 2008  36604337.0
# 2005  35827943.0
# 2006  36021202.0
# 2003  35253159.0
# 2004  35574576.0
# 2001  34479458.0
# 2002  34871843.0
# 1999  33499204.0
# 2000  33987977.0
# 1998  32987675.0
# 1997  32486010.0
# 1996  32018834.0
# 1995  31696582.0
# 1993  31274928.0
# 1994  31484435.0
# 1991  30470736.0
# 1992  30974659.0
# 1990  29959515.0

# %%
pops.loc[:,1990,:] # All states and year in 1990 and all populations
# Out:
#              population
# state year
# AL    1990    4050055.0
# AK    1990     553290.0
# AZ    1990    3684097.0
# AR    1990    2356586.0
# CA    1990   29959515.0
# CO    1990    3307618.0
# CT    1990    3291967.0
# DE    1990     669567.0
# DC    1990     605321.0
# FL    1990   13033307.0
# GA    1990    6512602.0
# HI    1990    1113491.0
# ID    1990    1012384.0
# IL    1990   11453316.0
# IN    1990    5557798.0
# IA    1990    2781018.0
# KS    1990    2481349.0
# KY    1990    3694048.0
# LA    1990    4221532.0
# ME    1990    1231719.0
# MD    1990    4799770.0
# MA    1990    6022639.0
# MI    1990    9311319.0
# MN    1990    4389857.0
# MS    1990    2578897.0
# MO    1990    5128880.0
# MT    1990     800204.0
# NE    1990    1581660.0
# NV    1990    1220695.0
# NH    1990    1112384.0
# NJ    1990    7762963.0
# NM    1990    1521574.0
# NY    1990   18020784.0
# NC    1990    6664016.0
# ND    1990     637685.0
# OH    1990   10864162.0
# ...

# %%
pops.loc[["CA","AK"],[1990,1991],:] # All states and year in 1990 and all populations
# Out:
#             population
# state year
# CA    1990  29959515.0
#       1991  30470736.0
# AK    1990    553290.0
#       1991    570193.0

# %%
pops.loc[["CA","AK"],[1990,1991],:].plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='state,year'>

# %%
pops.xs("CA",level=0)
# Out:
#       population
# year
# 2012  37999878.0
# 2011  37668681.0
# 2010  37333601.0
# 2013  38332521.0
# 2009  36961229.0
# 2007  36250311.0
# 2008  36604337.0
# 2005  35827943.0
# 2006  36021202.0
# 2003  35253159.0
# 2004  35574576.0
# 2001  34479458.0
# 2002  34871843.0
# 1999  33499204.0
# 2000  33987977.0
# 1998  32987675.0
# 1997  32486010.0
# 1996  32018834.0
# 1995  31696582.0
# 1993  31274928.0
# 1994  31484435.0
# 1991  30470736.0
# 1992  30974659.0
# 1990  29959515.0

# %%
pops.xs(2000,level=1)
# Out:
#         population
# state
# AL       4452173.0
# AK        627963.0
# AZ       5160586.0
# AR       2678588.0
# CA      33987977.0
# CO       4326921.0
# CT       3411777.0
# DE        786373.0
# DC        572046.0
# FL      16047515.0
# GA       8227303.0
# HI       1213519.0
# ID       1299430.0
# IL      12434161.0
# IN       6091866.0
# IA       2929067.0
# KS       2693681.0
# KY       4049021.0
# LA       4471885.0
# ME       1277072.0
# MD       5311034.0
# MA       6361104.0
# MI       9952450.0
# MN       4933692.0
# MS       2848353.0
# MO       5607285.0
# MT        903773.0
# NE       1713820.0
# NV       2018741.0
# NH       1239882.0
# NJ       8430621.0
# NM       1821204.0
# NY      19001780.0
# NC       8081614.0
# ND        642023.0
# OH      11363543.0
# OK       3454365.0
# OR       3429708.0
# PA      12284173.0
# RI       1050268.0
# SC       4024223.0
# SD        755844.0
# TN       5703719.0
# TX      20944499.0
# UT       2244502.0
# VT        609618.0
# ...

# %%
pops.index
# Out:
# MultiIndex([( 'AL', 2012),
#             ( 'AL', 2010),
#             ( 'AL', 2011),
#             ( 'AL', 2009),
#             ( 'AL', 2013),
#             ( 'AL', 2007),
#             ( 'AL', 2008),
#             ( 'AL', 2005),
#             ( 'AL', 2006),
#             ( 'AL', 2004),
#             ...
#             ('USA', 2004),
#             ('USA', 2005),
#             ('USA', 2006),
#             ('USA', 2007),
#             ('USA', 2008),
#             ('USA', 2013),
#             ('USA', 2009),
#             ('USA', 2010),
#             ('USA', 2011),
#             ('USA', 2012)],
#            names=['state', 'year'], length=1272)

# %%
pops.index.levels
# Out:
# FrozenList([['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'PR', 'RI', 'SC', 'SD', 'TN', 'TX', 'USA', 'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY'], [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013]])

# %%
pops.index.levels[0]
# Out:
# Index(['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA', 'HI',
#        'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME', 'MI', 'MN',
#        'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 'NY', 'OH',
#        'OK', 'OR', 'PA', 'PR', 'RI', 'SC', 'SD', 'TN', 'TX', 'USA', 'UT', 'VA',
#        'VT', 'WA', 'WI', 'WV', 'WY'],
#       dtype='object', name='state')

# %%
pops.index.levels[1]
# Out:
# Int64Index([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#             2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013],
#            dtype='int64', name='year')

# %%
pops.index.get_level_values(0)
# Out:
# Index(['AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL', 'AL',
#        ...
#        'USA', 'USA', 'USA', 'USA', 'USA', 'USA', 'USA', 'USA', 'USA', 'USA'],
#       dtype='object', name='state', length=1272)

# %%
pops.index.get_level_values(1)
# Out:
# Int64Index([2012, 2010, 2011, 2009, 2013, 2007, 2008, 2005, 2006, 2004,
#             ...
#             2004, 2005, 2006, 2007, 2008, 2013, 2009, 2010, 2011, 2012],
#            dtype='int64', name='year', length=1272)

# %%
pops.loc[:,[i for i in range(1990,2001,2)],:]
# Out:
#              population
# state year
# AL    1990    4050055.0
# AK    1990     553290.0
# AZ    1990    3684097.0
# AR    1990    2356586.0
# CA    1990   29959515.0
# ...                 ...
# WV    2000    1807021.0
# WI    2000    5373999.0
# WY    2000     494300.0
# PR    2000    3810605.0
# USA   2000  282162411.0
#
# [318 rows x 1 columns]

# %%
pops.loc[:,[i for i in range(1990,2001,2)],:].index.levels[1]
# Out:
# Int64Index([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#             2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#             2012, 2013],
#            dtype='int64', name='year')

# %%
pops.loc[:,[i for i in range(1990,1997,2)],:].head(20)
# Out:
#             population
# state year
# AL    1990   4050055.0
# AK    1990    553290.0
# AZ    1990   3684097.0
# AR    1990   2356586.0
# CA    1990  29959515.0
# CO    1990   3307618.0
# CT    1990   3291967.0
# DE    1990    669567.0
# DC    1990    605321.0
# FL    1990  13033307.0
# GA    1990   6512602.0
# HI    1990   1113491.0
# ID    1990   1012384.0
# IL    1990  11453316.0
# IN    1990   5557798.0
# IA    1990   2781018.0
# KS    1990   2481349.0
# KY    1990   3694048.0
# LA    1990   4221532.0
# ME    1990   1231719.0

# %%
pops[pops.index.get_level_values(0).str[1]=='A']
# Out:
#             population
# state year
# CA    2012  37999878.0
#       2011  37668681.0
#       2010  37333601.0
#       2013  38332521.0
#       2009  36961229.0
# ...                ...
# WA    2013   6971406.0
#       2009   6667426.0
#       2010   6742256.0
#       2011   6821481.0
#       2012   6895318.0
#
# [192 rows x 1 columns]

# %%
pops.unstack(level="state")
# Out:
#       population                                                          \
# state         AK         AL         AR         AZ          CA         CO
# year
# 1990    553290.0  4050055.0  2356586.0  3684097.0  29959515.0  3307618.0
# 1991    570193.0  4099156.0  2383144.0  3788576.0  30470736.0  3387119.0
# 1992    588736.0  4154014.0  2415984.0  3915740.0  30974659.0  3495939.0
# 1993    599434.0  4214202.0  2456303.0  4065440.0  31274928.0  3613734.0
# 1994    603308.0  4260229.0  2494019.0  4245089.0  31484435.0  3724168.0
# 1995    604412.0  4296800.0  2535399.0  4432499.0  31696582.0  3826653.0
# 1996    608569.0  4331103.0  2572109.0  4586940.0  32018834.0  3919972.0
# 1997    612968.0  4367935.0  2601091.0  4736990.0  32486010.0  4018293.0
# 1998    619933.0  4404701.0  2626289.0  4883342.0  32987675.0  4116639.0
# 1999    624779.0  4430141.0  2651860.0  5023823.0  33499204.0  4226018.0
# 2000    627963.0  4452173.0  2678588.0  5160586.0  33987977.0  4326921.0
# ...

# %%
titanic.groupby(["pclass","sex"])["age"].count()
# Out:
# pclass  sex
# 1       female    144
#         male      179
# 2       female    106
#         male      171
# 3       female    216
#         male      493
# Name: age, dtype: int64

# %%
titanic.groupby(["pclass","sex"])["age"].count().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='pclass,sex'>

# %%
titanic.groupby(["pclass","sex"])["age"].count().unstack()
# Out:
# sex     female  male
# pclass
# 1          144   179
# 2          106   171
# 3          216   493

# %%
titanic.groupby(["pclass","sex"])["age"].count().unstack().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='pclass'>

# %%
titanic.groupby(["pclass","sex"])["age"].count().unstack(level="pclass").plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
titanic.groupby(["pclass","sex"])["age"].count().unstack(level="sex").plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='pclass'>

# %%
titanic.groupby(["sex","survived"])["age"].count()
# Out:
# sex     survived
# female  0           127
#         1           339
# male    0           682
#         1           161
# Name: age, dtype: int64

# %%
titanic.groupby(["sex","survived"])["age"].count().unstack().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='sex'>
