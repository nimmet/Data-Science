# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
house = pd.read_csv("C:/Data_Science/Python_Data_Analyse_Visualization/data/kc_house_data.csv")
titanic = pd.read_csv("C:/Data_Science/Python_Data_Analyse_Visualization/data/titanic.csv")
netflix  = pd.read_csv("C:/Data_Science/Python_Data_Analyse_Visualization/data/netflix_titles.csv",sep="|", index_col=0)
btc = pd.read_csv("C:/Data_Science/Python_Data_Analyse_Visualization/data/coin_Bitcoin.csv")
countries = pd.read_csv("C:/Data_Science/Python_Data_Analyse_Visualization/data/world-happiness-report-2021.csv", index_col=0)
car = pd.read_csv("C:/Data_Science/Python_Data_Analyse_Visualization/data/car_stocks.csv")
pops = pd.read_csv("C:/Data_Science/Python_Data_Analyse_Visualization/data/state_pops.csv")

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
penguins = sns.load_dataset('penguins')
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.set_theme()

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip",hue="sex")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip",hue="smoker")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip",hue="sex", style="time")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip",hue="sex", style="sex")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip",hue="sex", style="day")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip",hue="sex", size="size")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # Line Plots

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
sns.lineplot(data=flights,x="year",y="passengers")
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
sns.lineplot(data=flights,x="year",y="passengers", estimator="sum")
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
sns.lineplot(data=flights,x="year",y="passengers", estimator="max")
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
sns.lineplot(data=flights,x="year",y="passengers", estimator="min")
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
flights.groupby("year")["passengers"].mean().plot()
# Out:
# <AxesSubplot:xlabel='year'>

# %%
sns.lineplot(data=flights,x="year",y="passengers")
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
sns.lineplot(data=flights,x="year",y="passengers", hue="month")
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
trips= sns.load_dataset("taxis", parse_dates=["pickup", "dropoff"])

# %%
trips["hour"] = trips["pickup"].dt.hour

# %%
trips
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
sns.lineplot(data=trips, x="hour", y="total", hue="payment", style="color", ci=None)
# Out:
# <AxesSubplot:xlabel='hour', ylabel='total'>

# %% [markdown]
# # RelPlot

# %%
sns.relplot(data=tips, x="total_bill", y="tip", kind="scatter", col="sex")

# %%
sns.relplot(data=tips, x="total_bill", y="tip", kind="scatter", hue="smoker")

# %%
sns.relplot(data=tips, x="total_bill", y="tip", kind="scatter", hue="smoker",col="sex")

# %%
sns.relplot(data=tips, x="total_bill", y="tip", kind="scatter", col="sex", row="time")

# %%
sns.relplot(data=tips, x="total_bill", y="tip", kind="scatter", col="sex", row="day", hue="smoker")

# %%
sns.relplot(data=trips, x='hour',y='total',kind="line",col="pickup_borough")

# %%
sns.relplot(data=trips, x='hour',y='total',kind="line",col="pickup_borough",hue="payment")

# %%
sns.relplot(data=trips, x='hour',y='total',kind="line",col="pickup_borough",hue="payment", row="dropoff_borough")

# %% [markdown]
# # Change Size

# %%
plt.figure(figsize=(8,5))
sns.lineplot(data=flights, x="year",y='passengers',hue="month")
# Out:
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
sns.relplot(data=tips, x="total_bill",
            y="tip", kind="scatter",
            hue="smoker",col="sex",
            row="day",
            height=4, # we can determine the size of plot from here
            aspect=1.5 # we can determine the width of plot with aspect parameter
           )

# %% [markdown]
# # Displot

# %%
sns.histplot(data=tips,x="tip")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
sns.histplot(data=tips,x="tip", hue="sex")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
sns.histplot(data=tips,x="tip", hue="time")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
sns.histplot(data=tips,x="tip", hue="sex", multiple="stack")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %%
sns.histplot(data=tips,x="tip", hue="sex", multiple="dodge")
# Out:
# <AxesSubplot:xlabel='tip', ylabel='Count'>

# %% [markdown]
# # KDE Plot

# %%
sns.kdeplot(data=penguins,x="body_mass_g",hue="species")
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='Density'>

# %%
sns.kdeplot(data=penguins,x="body_mass_g",hue="species",bw_adjust=0.2)
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='Density'>

# %%
sns.kdeplot(data=penguins,x="body_mass_g",hue="species",bw_adjust=0.5)
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='Density'>

# %%
sns.kdeplot(data=penguins,x="body_mass_g",hue="species",multiple="stack")
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='Density'>

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.histplot(data=penguins,x="body_mass_g")
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='Count'>

# %%
sns.histplot(data=penguins,x="flipper_length_mm")
# Out:
# <AxesSubplot:xlabel='flipper_length_mm', ylabel='Count'>

# %%
sns.histplot(data=penguins,x="body_mass_g", y="flipper_length_mm")
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
sns.kdeplot(data=penguins,x="body_mass_g", y="flipper_length_mm")
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
sns.kdeplot(data=penguins,x="body_mass_g", y="flipper_length_mm", hue="species")
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %%
sns.kdeplot(data=penguins,x="bill_length_mm", y="flipper_length_mm", hue="species")
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %%
sns.histplot(data=penguins,x="bill_length_mm", y="flipper_length_mm", hue="species")
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %% [markdown]
# # Rugplot

# %%
sns.rugplot(data=tips,x="tip", height=0.5)
# Out:
# <AxesSubplot:xlabel='tip'>

# %%
sns.rugplot(data=tips,y="tip", height=0.5)
# Out:
# <AxesSubplot:ylabel='tip'>

# %%
sns.kdeplot(data=tips, x="total_bill")
sns.rugplot(data=tips, x="total_bill", height=0.2)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.scatterplot(data=tips, x="total_bill",y="tip")
sns.rugplot(data=tips, x="total_bill",y="tip")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
diamonds = sns.load_dataset("diamonds")
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sns.scatterplot(data=diamonds, x="carat",y="price",s=5)
sns.rugplot(data=diamonds, x="carat",y="price",lw=1,alpha=.005)
# Out:
# <AxesSubplot:xlabel='carat', ylabel='price'>

# %% [markdown]
# # Displot

# %%
sns.displot(kind="hist",data=penguins,x="body_mass_g", height=3, aspect=2)

# %%
sns.displot(kind="kde",data=penguins,x="body_mass_g", height=3, aspect=2)

# %%
sns.displot(kind="kde",data=penguins,x="body_mass_g",col="species", height=3, aspect=2)

# %%
sns.displot(kind="hist",data=penguins,x="body_mass_g",col="species")
sns.displot(kind="kde",data=penguins,x="body_mass_g",col="species")

# %%
sns.displot(kind="hist",data=penguins,x="body_mass_g",col="species", hue="sex")

# %%
sns.displot(kind="hist",data=penguins,x="body_mass_g",col="species", hue="sex", row="island")

# %%
sns.displot(data=tips, kind="kde", x="tip", col="time", rug=True)

# %%
sns.displot(data=tips, kind="kde",x="total_bill", y="tip", col="time", rug=True)

# %% [markdown]
# # Countplot

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.countplot(data=penguins, x="species")
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %%
sns.countplot(data=penguins, x="species",hue="sex")
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %%
sns.countplot(data=titanic, x='pclass')
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='count'>

# %%
sns.countplot(data=titanic, x='pclass', hue="sex")
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='count'>

# %%
sns.countplot(data=titanic, y="pclass", hue="sex")
# Out:
# <AxesSubplot:xlabel='count', ylabel='pclass'>
